# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Alicia/Downloads/archive/AWCustomers.csv")

# %%
# Out:
# dtype('int64')

# %%
data
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
#select customerid, lastname from data where gender != 'M' and Occupation = 'Clerical'

data[(data['Gender'] != 'M') | (data['Occupation'] == 'Clerical')][['CustomerID','LastName']]
# Out:
#        CustomerID  LastName
# 0           21173      Yuan
# 1           13249     Perry
# 2           29350  Thompson
# 5           22092     Young
# 7           24179    Blanco
# ...           ...       ...
# 18356       25414    Bailey
# 18357       11459      Deng
# 18358       12160     Zhang
# 18359       14353      Reed
# 18360       16676     Perry
#
# [11329 rows x 2 columns]

# %%
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_16448\3769639722.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data2[data['LastName'].isna()]
# Empty DataFrame
# Columns: [CustomerID, LastName]
# Index: []

# %%
data
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
#select *  from data where title is not null
#data[data['Title'].notna()]
#data['Title'].isna()

#Update title column tp Mr

male_na_data = data[ (data['Gender'] == 'M') & (data['Title'].isna()) ]

# %%
male_na_data['Title'].fillna('Mr', inplace=True)
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_16448\395686042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_na_data['Title'].fillna('Mr', inplace=True)

# %%
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_16448\1932774201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_na_data['Mine'] = "Yes"

# %%
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_16448\2450462309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_na_data.drop(columns=['Mine'],inplace=True)

# %%
male_na_data
# Out:
#        CustomerID Title FirstName MiddleName   LastName Suffix  \
# 0           21173    Mr      Chad          C       Yuan    NaN
# 1           13249    Mr      Ryan        NaN      Perry    NaN
# 3           13503    Mr  Theodore        NaN      Gomez    NaN
# 4           22803    Mr  Marshall          J       Shan    NaN
# 6           11229    Mr    Adrian          C    Stewart    NaN
# ...           ...   ...       ...        ...        ...    ...
# 18343       29310    Mr   Armando        NaN  Gutierrez    NaN
# 18347       29064    Mr      Jose        NaN     Butler    NaN
# 18348       11287    Mr     Henry          B     Garcia    NaN
# 18349       11465    Mr     Louis        NaN        Luo    NaN
# 18355       14522    Mr      Omar          C      Zheng    NaN
#
#               AddressLine1 AddressLine2          City    StateProvinceName  \
# 0       7090 C. Mount Hood          NaN    Wollongong      New South Wales
# ...

# %%
male_na_data['FirstName'].str.upper()
# Out:
# 0            CHAD
# 1            RYAN
# 3        THEODORE
# 4        MARSHALL
# 6          ADRIAN
#            ...
# 18343     ARMANDO
# 18347        JOSE
# 18348       HENRY
# 18349       LOUIS
# 18355        OMAR
# Name: FirstName, Length: 9235, dtype: object

# %%
male_na_data['Name_Upper'] = male_na_data['FirstName'].str.upper()
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_16448\1697798690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_na_data['Name_Upper'] = male_na_data['FirstName'].str.upper()

# %%
male_na_data.drop(columns=['FirstName'],inplace=True)
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_16448\1549580406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_na_data.drop(columns=['FirstName'],inplace=True)

# %%
male_na_data

#drop column
#create a new column
#convert a string to upper or lower case


Create new : FullName
Mr. Lastname Middlename Firstname
# Out:
#        CustomerID Title MiddleName   LastName Suffix         AddressLine1  \
# 0           21173    Mr          C       Yuan    NaN   7090 C. Mount Hood
# 1           13249    Mr        NaN      Perry    NaN  3651 Willow Lake Rd
# 3           13503    Mr        NaN      Gomez    NaN      2103 Baldwin Dr
# 4           22803    Mr          J       Shan    NaN      Am Gallberg 234
# 6           11229    Mr          C    Stewart    NaN        6898 Shaw Rd.
# ...           ...   ...        ...        ...    ...                  ...
# 18343       29310    Mr        NaN  Gutierrez    NaN   8364 Encinal Place
# 18347       29064    Mr        NaN     Butler    NaN      2109 Harvey Way
# 18348       11287    Mr          B     Garcia    NaN  3268 Hazelwood Lane
# 18349       11465    Mr        NaN        Luo    NaN    4187 Banbury Loop
# 18355       14522    Mr          C      Zheng    NaN   8527 Rock Oak Road
#
#       AddressLine2          City    StateProvinceName CountryRegionName  ...  \
# ...

# %%
male_na_data['FullName'] =  male_na_data['Title'].str.upper() + ' ' + male_na_data['FirstName'].str.upper() + ' ' + male_na_data['MiddleName'].str.upper() + ' ' + male_na_data['LastName'].str.upper()
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_16448\3196844312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_na_data['FullName'] =  male_na_data['Title'].str.upper() + ' ' + male_na_data['FirstName'].str.upper() + ' ' + male_na_data['MiddleName'].str.upper() + ' ' + male_na_data['LastName'].str.upper()

# %%
male_not_na = male_na_data[male_na_data['FullName'].notna()][['Title','FirstName','MiddleName','LastName','FullName']]

# %%
male_not_na
# Out:
#       Title FirstName MiddleName LastName              FullName
# 0        Mr      Chad          C     Yuan        MR CHAD C YUAN
# 4        Mr  Marshall          J     Shan    MR MARSHALL J SHAN
# 6        Mr    Adrian          C  Stewart   MR ADRIAN C STEWART
# 9        Mr    Marcus          N   Nelson    MR MARCUS N NELSON
# 11       Mr      Alex          J   Turner      MR ALEX J TURNER
# ...     ...       ...        ...      ...                   ...
# 18331    Mr      Luke          M   Carter      MR LUKE M CARTER
# 18338    Mr  Fernando          R   Harris  MR FERNANDO R HARRIS
# 18341    Mr    Kelvin          A     Zeng      MR KELVIN A ZENG
# 18348    Mr     Henry          B   Garcia     MR HENRY B GARCIA
# 18355    Mr      Omar          C    Zheng       MR OMAR C ZHENG
#
# [5331 rows x 5 columns]

# %%
male_not_na.sort_values(by=['FirstName','MiddleName'], inplace = True, ascending = False)

# %%
male_not_na['YearlyIncome'] = data['YearlyIncome']

# %%
male_not_na['YearlyIncome'].min()
# Out:
# 25583

# %%
male_not_na['YearlyIncome'].max()
# Out:
# 139115

# %%
male_not_na['YearlyIncome'].var()
# Out:
# 959942170.5016526

# %%
#select FirstName, sum(YearlyIncome) as sum, avg(YearlyIncome)  as mean, min(YearlyIncome) as min, max(YearlyIncome) as max
#from male_not_na
#group by FirstName

male_not_na.groupby(['FirstName','LastName'])['YearlyIncome'].agg(['sum','mean','min','max','count'])
# Out:
#                        sum      mean     min     max  count
# FirstName LastName
# Aaron     Adams      53728   53728.0   53728   53728      1
#           Allen      28827   28827.0   28827   28827      1
#           Baker      60460   60460.0   60460   60460      1
#           Campbell  104451  104451.0  104451  104451      1
#           Carter     56521   56521.0   56521   56521      1
# ...                    ...       ...     ...     ...    ...
# Zachary   Thomas     59071   59071.0   59071   59071      1
#           Thompson   34060   34060.0   34060   34060      1
#           Walker     61847   61847.0   61847   61847      1
#           Williams   61157   61157.0   61157   61157      1
#           Yang      135477  135477.0  135477  135477      1
#
# [5325 rows x 5 columns]

# %%
male_not_na
# Out:
#       Title FirstName MiddleName   LastName                FullName  \
# 12175    Mr   Zachary          W      Smith      MR ZACHARY W SMITH
# 4973     Mr   Zachary          S      Moore      MR ZACHARY S MOORE
# 11285    Mr   Zachary          R  Patterson  MR ZACHARY R PATTERSON
# 11746    Mr   Zachary          R   Thompson   MR ZACHARY R THOMPSON
# 11666    Mr   Zachary          M     Miller     MR ZACHARY M MILLER
# ...     ...       ...        ...        ...                     ...
# 12095    Mr     Aaron          C       Diaz         MR AARON C DIAZ
# 17395    Mr     Aaron          B      Adams        MR AARON B ADAMS
# 18082    Mr     Aaron          A      Zhang        MR AARON A ZHANG
# 12907    Mr     Aaron          A      Hayes        MR AARON A HAYES
# 16780    Mr     Aaron          A      Allen        MR AARON A ALLEN
#
#        YearlyIncome
# 12175         80474
# 4973          55402
# 11285         57337
# 11746         34060
# 11666         31103
# ...             ...
# ...

# %%
# Out:
# '7090 C. Mount Hood'

# %%
address = data['AddressLine1'][0]

# %%
address
# Out:
# '7090 C. Mount Hood'

# %%
#split
address.split(' ')[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11816\3010939065.py in <module>
#       1 #split
# ----> 2 address.split(' ')[4]
#
# IndexError: list index out of range

# %%
data1 = '11-05-2025'

# %%
Year = data1.split('-')[2]
Month = data1.split('-')[1]
day = data1.split('-')[0]

# %%
day
# Out:
# '11'

# %%
data
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
data['LastUpdated'].dtype
# Out:
# dtype('O')

# %%
data[['Year','Month','Day']] = data['LastUpdated'].str.split('-', 3 , expand =True)

# %%
data
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
address
# Out:
# '7090 C. Mount Hood'

# %%
address[8:-10]
# Out:
# ''

# %%
data['YearlyIncome'] = data['YearlyIncome'].astype(str)

# %%
data['YearlyIncome'].dtype
# Out:
# dtype('O')

# %%
data['YearlyIncome'].astype(int)
# Out:
# 0         81916
# 1         81076
# 2         86387
# 3         61481
# 4         51804
#           ...
# 18356     52953
# 18357     60992
# 18358     51859
# 18359     87177
# 18360    136856
# Name: YearlyIncome, Length: 18361, dtype: int32

# %%
name = ['Femi','Titobi','Afolabi','Isaiah']
deg = ['Btech','Bsc','Mba','Phd']
scr = [90,98,91,95]
addy = ['No 10', 'Plot 15', 'House 2', 'Flat12']

dict1 = {'name': name, 'degree':deg, 'score': scr}
dict2 = {'name': name, 'address': addy}

df1 = pd.DataFrame(dict1)
df2 = pd.DataFrame(dict2)

# %%
df3 = pd.DataFrame([['Femi','Titobi','Afolabi','Isaiah'],['Btech','Bsc','Mba','Phd'],[90,98,91,95]])

# %%
df3
# Out:
#        0       1        2       3
# 0   Femi  Titobi  Afolabi  Isaiah
# 1  Btech     Bsc      Mba     Phd
# 2     90      98       91      95

# %%
df1
# Out:
#       name degree  score
# 0     Femi  Btech     90
# 1   Titobi    Bsc     98
# 2  Afolabi    Mba     91
# 3   Isaiah    Phd     95

# %%
df2
# Out:
#       name  address
# 0     Femi    No 10
# 1   Titobi  Plot 15
# 2  Afolabi  House 2
# 3   Isaiah   Flat12

# %%
df3 = pd.merge(df2, df1, on = 'name')

# %%
df3
# Out:
#       name  address degree  score
# 0     Femi    No 10  Btech     90
# 1   Titobi  Plot 15    Bsc     98
# 2  Afolabi  House 2    Mba     91
# 3   Isaiah   Flat12    Phd     95

# %%
df3.to_csv(r'c:\femi.csv')
